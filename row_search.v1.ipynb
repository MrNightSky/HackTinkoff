# %%
import sys
import gensim, logging
import pandas as pd
import os
import numpy as np
import gensim.downloader as api

model = api.load("word2vec-ruscorpora-300")

# %%
def Search_column_content(data,Search_content,file_name,noun_bonus=1,adj_bonus=1):
    """
    Content - pd.Series с контентом.
    Search_content - List с контентом(!) поиска [горный_NOUN,горный_ADJ,....]  
    
    Выход - по датафрейм (Similarity | id(просто чтобы не просрать) | магазин.csv)
    
    """
    new_data = data.copy()
    Similarity=[]
    for row in new_data.words:
        #row строка вида велосипед_NOUN,велосипед_ADJ, и тд
        content_words=row.split(',')
        Final_rating=[]

        for word in Search_content:
            coef=1
            if word.split('_')[1]=='NOUN':
                coef=noun_bonus
            else:
                coef=adj_bonus
            ratings=[]
            for cont in content_words:
                #print(word,cont)
                
                ratings.append(model.similarity(word, cont)*coef)
            Final_rating.append(np.mean(ratings))
        Similarity.append(np.mean(Final_rating))
    
    name = np.full(new_data.shape[0], file_name)
    new_data['Similarity'] = np.array(Similarity)
    new_data['Name'] = name
    return new_data

# %%
DATA_PATH = 'D:\Мой диск\Pr\Py\Challenges\hackProf\HackTinkoff\data\\added_data'
DATA_PATH = '.\data\\added_data'
Category='Food'
os.chdir(DATA_PATH)
File_names_by_cat={'Sport':['double-sport.csv'],'Food':['abrikos.csv', 'auchan.csv', 'foodband.csv'],'Tablets':['iherb_food.csv', 'gold-standart.csv']}
text=['яблоко_NOUN','красное_NOUN','красный_ADJ']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-228280bcfca2> in <module>()
#       2 DATA_PATH = '.\data\\added_data'
#       3 Category='Food'
# ----> 4 os.chdir(DATA_PATH)
#       5 File_names_by_cat={'Sport':['double-sport.csv'],'Food':['abrikos.csv', 'auchan.csv', 'foodband.csv'],'Tablets':['iherb_food.csv', 'gold-standart.csv']}
#       6 text=['яблоко_NOUN','красное_NOUN','красный_ADJ']
#
# FileNotFoundError: [WinError 3] Системе не удается найти указанный путь: '.\\data\\added_data'

# %%
CUR_PATH = os.getcwd()

# %%
def Total_search(Category,Search_content): 
    """
    File_names = File_names_by_cat[Category]
    Search_content - Обработанная строка поиска в виде List
    
    Выход - отсортированный по Similarity descending полный Dataframe вида (Similarity | id(в оригинальном файле) | магазин.csv)
    
    """
    CUR_PATH = os.getcwd()
    os.chdir(DATA_PATH)
    File_names = File_names_by_cat[Category]
    All_similarities=[]
    for file in File_names:
        current_file = pd.read_csv(file)
        All_similarities.append(Search_column_content(current_file,Search_content,file,2,0.75))
    pre_data = pd.concat(All_similarities, axis=0).sort_values(by=['Similarity'], ascending=False)
    os.chdir(CUR_PATH)
    return pd.DataFrame(pre_data.values, index=range(pre_data.shape[0]), columns=pre_data.columns)

# %%
DATA_PATH = '.\data\\added_data'
File_names_by_cat={'Sport':['double-sport.csv'],'Food':['abrikos.csv', 'auchan.csv', 'foodband.csv'],'Tablets':['iherb_food.csv', 'gold-standart.csv']}
text=['яблоко_NOUN','красное_NOUN','красный_ADJ']
# 26    \r\nШаг заказа 2 кг. Итоговый вес и сумма може...    39
# 27                \r\nЦукаты персик фасовка, 250 г.\r\n   225
# 28    Цена за 1кг. Итоговый вес и сумма могут незнач...   320
# 29                                                  NaN   225
# ...                                                 ...   ...
# 9547                                                NaN  1100
# 9548                                                NaN   465
# 9549                                                NaN   548
# 9550                                                NaN   684
# 9551  Производитель: "Проктер энд Гэмбл-Новомосковск...    89
# 9552  Производитель: "Проктер энд Гэмбл-Новомосковск...   270
# 9553                                                NaN   107
# 9554  \r\n\tПроизводитель: ООО "Проктер энд Гэмбл-Но...  1500
# 9555                                                NaN   824
# 9556  \r\n\tПроизводитель: ООО "Проктер энд Гэмбл-Но...  1115
# 9557  Производитель: ООО "Хенкель-Рус", Россия.Стира...   850
# 9558  Производитель: ООО "Хенкель-Рус", Россия.Стира...    74
# 9559  Производитель: ООО "Хенкель-Рус", Россия.Стира...    85
# 9560  \r\n\tПроизводитель: ООО "Хенкель-Рус", Россия...   870
# 9561                                                NaN  2578
# 9562                                                NaN  2400
# 9563  \r\n\tПроизводитель: ООО "Хенкель-Рус", Россия...   450
# 9564  Производитель: ООО "Хенкель-Рус", Россия.Стира...  1180
# 9565                                                NaN   524
# 9566                                                NaN   660
# 9567                                                NaN   260
# 9568                                                NaN   371
# 9569                                                NaN   624
# 9570                                                NaN   227
# 9571                                                NaN   227
# 9572                                       ООО «Айпэкс»  3540
# 9573                                       ООО «Айпэкс»   270
# 9574                                      ООО «Айпэкс»    925
# 9575                                                NaN   182
# 9576                                                NaN   660
#
#                                                   words Similarity  \
# 0                              яблоко_NOUN,напиток_NOUN    0.54201
# 1                              яблоко_NOUN,напиток_NOUN    0.54201
# 2                  яблоко_NOUN,моченый_ADJ,соление_NOUN   0.517237
# 3     яблоко_NOUN,овощ_NOUN,гриб_NOUN,фрукт_NOUN,яго...   0.489207
# 4                 фундук_NOUN,сухофрукты_NOUN,орех_NOUN   0.471543
# 5     овощ_NOUN,гриб_NOUN,красный_ADJ,репчатый_ADJ,ф...   0.463314
# 6     овощ_NOUN,гриб_NOUN,красный_ADJ,фрукт_NOUN,яго...   0.463254
# 7     овощ_NOUN,гриб_NOUN,виноград_NOUN,фрукт_NOUN,я...   0.462234
# 8     яблоко_NOUN,овощ_NOUN,гриб_NOUN,фрукт_NOUN,яго...   0.457679
# 9     овощ_NOUN,гриб_NOUN,виноград_NOUN,фрукт_NOUN,я...   0.455368
# 10      сухофрукты_NOUN,цукат_NOUN,орех_NOUN,вишня_NOUN   0.452214
# 11    овощ_NOUN,гриб_NOUN,желтый_ADJ,фрукт_NOUN,ягод...   0.451382
# 12    фундук_NOUN,сухофрукты_NOUN,жареный_ADJ,орех_NOUN   0.450668
# 13    овощ_NOUN,гриб_NOUN,репчатый_ADJ,фрукт_NOUN,лу...   0.448705
# 14    овощ_NOUN,гриб_NOUN,виноград_NOUN,фрукт_NOUN,ч...   0.447781
# 15    цитрусовый_ADJ,овощ_NOUN,гриб_NOUN,красный_ADJ...   0.445931
# 16    овощ_NOUN,гриб_NOUN,красный_ADJ,редис_NOUN,фру...   0.445078
# 17    овощ_NOUN,гриб_NOUN,красный_ADJ,фрукт_NOUN,пер...    0.44353
# 18    овощ_NOUN,гриб_NOUN,репчатый_ADJ,фрукт_NOUN,по...    0.43973
# 19    клюква_NOUN,сухофрукты_NOUN,орех_NOUN,сушеный_ADJ   0.439373
# 20    овощ_NOUN,гриб_NOUN,фрукт_NOUN,ягода_NOUN,анан...   0.439291
# 21    яблоко_NOUN,красный_ADJ,продукт_NOUN,сухарик_N...   0.439024
# 22    овощ_NOUN,гриб_NOUN,фрукт_NOUN,клубника_NOUN,я...   0.437498
# 23    овощ_NOUN,гриб_NOUN,репчатый_ADJ,фрукт_NOUN,лу...   0.436922
# 24    овощ_NOUN,гриб_NOUN,репчатый_ADJ,фрукт_NOUN,лу...   0.436922
# 25    овощ_NOUN,гриб_NOUN,фрукт_NOUN,томат_NOUN,свеж...   0.436792
# 26    овощ_NOUN,гриб_NOUN,фрукт_NOUN,белокочанный_AD...   0.435115
# 27     сухофрукты_NOUN,цукат_NOUN,орех_NOUN,персик_NOUN   0.434778
# 28    овощ_NOUN,гриб_NOUN,фрукт_NOUN,ягода_NOUN,свеж...   0.434692
# 29                 красный_ADJ,чеснок_NOUN,соление_NOUN   0.434615
# ...                                                 ...        ...
# 9547  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9548  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9549  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9550  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9551  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9552  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9553  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9554  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9555  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9556  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9557  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9558  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9559  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9560  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9561  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9562  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9563  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9564  средство_NOUN,автомат_NOUN,стиральный_ADJ,хозя...   0.135094
# 9565  средство_NOUN,сухость_NOUN,дезодорант_NOUN,ком...   0.134915
# 9566  средство_NOUN,бритье_NOUN,лосьон_NOUN,косметич...   0.134758
# 9567  средство_NOUN,чистота_NOUN,комфорт_NOUN,гель_N...   0.133729
# 9568  средство_NOUN,ласка_NOUN,хозяйственный_ADJ,быт...   0.133478
# 9569  средство_NOUN,ласка_NOUN,хозяйственный_ADJ,быт...   0.133478
# 9570  средство_NOUN,дезодорант_NOUN,антиперспирант_N...   0.132272
# 9571  средство_NOUN,дезодорант_NOUN,бережный_ADJ,ант...    0.13114
# 9572      средство_NOUN,моющий_ADJ,профессиональный_ADJ   0.130974
# 9573      средство_NOUN,моющий_ADJ,профессиональный_ADJ   0.130974
# 9574      средство_NOUN,моющий_ADJ,профессиональный_ADJ   0.130974
# 9575  средство_NOUN,экстрим_NOUN,гель_NOUN,охлаждени...   0.130064
# 9576  средство_NOUN,комфорт_NOUN,бритье_NOUN,лосьон_...    0.12357
#
#               Name
# 0     foodband.csv
# 1     foodband.csv
# 2      abrikos.csv
# 3      abrikos.csv
# 4      abrikos.csv
# 5      abrikos.csv
# 6      abrikos.csv
# 7      abrikos.csv
# 8      abrikos.csv
# 9      abrikos.csv
# 10     abrikos.csv
# 11     abrikos.csv
# 12     abrikos.csv
# 13     abrikos.csv
# 14     abrikos.csv
# 15     abrikos.csv
# 16     abrikos.csv
# 17     abrikos.csv
# 18     abrikos.csv
# 19     abrikos.csv
# 20     abrikos.csv
# 21      auchan.csv
# 22     abrikos.csv
# 23     abrikos.csv
# 24     abrikos.csv
# 25     abrikos.csv
# 26     abrikos.csv
# 27     abrikos.csv
# 28     abrikos.csv
# 29     abrikos.csv
# ...            ...
# 9547   abrikos.csv
# 9548   abrikos.csv
# 9549   abrikos.csv
# 9550   abrikos.csv
# 9551   abrikos.csv
# 9552   abrikos.csv
# 9553   abrikos.csv
# 9554   abrikos.csv
# 9555   abrikos.csv
# 9556   abrikos.csv
# 9557   abrikos.csv
# 9558   abrikos.csv
# 9559   abrikos.csv
# 9560   abrikos.csv
# 9561   abrikos.csv
# 9562   abrikos.csv
# 9563   abrikos.csv
# 9564   abrikos.csv
# 9565   abrikos.csv
# 9566   abrikos.csv
# 9567   abrikos.csv
# 9568   abrikos.csv
# 9569   abrikos.csv
# 9570   abrikos.csv
# 9571   abrikos.csv
# 9572   abrikos.csv
# 9573   abrikos.csv
# 9574   abrikos.csv
# 9575   abrikos.csv
# 9576   abrikos.csv
#
# [9577 rows x 7 columns]

# %%
data = pd.read_csv(result.Shop[0])
data.loc[result['ID'][0]]
# Out:
# Unnamed: 0                                                  108
# Название                                    напиток~Rich Яблоко
# Описание      Сочное, спелое яблоко создает особый благородн...
# Цена                                                        175
# words                                  яблоко_NOUN,напиток_NOUN
# Name: 108, dtype: object
